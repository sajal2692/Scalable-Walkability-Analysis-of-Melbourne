# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
dframe = pd.read_csv('innermelbourne.csv')
dframe.columns = dframe.columns.str.strip()

# %%
#Dropping columns deemed irrelevant
aframe = dframe.drop(['gcc_name11','gcc_code11','sa2_5dig11','sa1_7dig11','sa3_code11','sa4_code11','ste_code11','ste_name11'],axis=1)

# %%
aframe
# Out:
#        sa1_main11              sa2_name11          sa3_name11  \
# 0     20602111008  Alphington - Fairfield     Darebin - South
# 1     20604112615               Southbank      Melbourne City
# 2     20601110506               Brunswick  Brunswick - Coburg
# 3     20606113726      South Yarra - East  Stonnington - West
# 4     20606113730      South Yarra - East  Stonnington - West
# 5     20606113731      South Yarra - East  Stonnington - West
# 6     20606113801                  Toorak  Stonnington - West
# 7     20606113802                  Toorak  Stonnington - West
# 8     20606113803                  Toorak  Stonnington - West
# 9     20606113804                  Toorak  Stonnington - West
# 10    20606113805                  Toorak  Stonnington - West
# 11    20606113806                  Toorak  Stonnington - West
# 12    20606113807                  Toorak  Stonnington - West
# 13    20601110507               Brunswick  Brunswick - Coburg
# ...

# %%
#Selecting single entry
aframe.ix[0]
# Out:
# sa1_main11                             20602111008
# sa2_name11                  Alphington - Fairfield
# sa3_name11                         Darebin - South
# sa4_name11                       Melbourne - Inner
# Connectivity                               91.8798
# Area                                        206792
# Connections                                     19
# LUM_Residential                             184936
# LUM_Industrial                             21855.5
# LUM_Commercial                                   0
# LUM_Parkland                                     0
# LUM_Education                                    0
# LandUseMixMeasure                         0.209642
# AverageDensity                             38.1262
# Connectivity_ZScore                        -1.0899
# AverageDensity_ZScore                    -0.608101
# LandUseMixMeasure_ZScore                 -0.639684
# SumZScore                                 -2.33768
# Name: 0, dtype: object

# %%
#Querying the dataframe
aframe[aframe['SumZScore'] > 10]
# Out:
#        sa1_main11 sa2_name11      sa3_name11         sa4_name11  Connectivity  \
# 1     20604112615  Southbank  Melbourne City  Melbourne - Inner    259.133836
# 111   20604112616  Southbank  Melbourne City  Melbourne - Inner    373.917000
# 215   20604112617  Southbank  Melbourne City  Melbourne - Inner    312.176354
# 636   20604112618  Southbank  Melbourne City  Melbourne - Inner    321.409626
# 843   20604112623  Southbank  Melbourne City  Melbourne - Inner    258.344678
# 963   20604112613  Southbank  Melbourne City  Melbourne - Inner    335.511615
# 1074  20604112614  Southbank  Melbourne City  Melbourne - Inner    259.208548
#
#                Area  Connections  LUM_Residential  LUM_Industrial  \
# 1     239258.605003           62     60400.955144    90046.798515
# 111   219300.005003           82     45391.831700    92560.962728
# 215   243452.135004           76     54907.212188   103387.199027
# 636   245792.265004           79     53408.224597   105737.759176
# ...

# %%
aframe.columns
# Out:
# Index([u'sa1_main11', u'sa2_name11', u'sa3_name11', u'sa4_name11',
#        u'Connectivity', u'Area', u'Connections', u'LUM_Residential',
#        u'LUM_Industrial', u'LUM_Commercial', u'LUM_Parkland', u'LUM_Education',
#        u'LandUseMixMeasure', u'AverageDensity', u'Connectivity_ZScore',
#        u'AverageDensity_ZScore', u'LandUseMixMeasure_ZScore', u'SumZScore'],
#       dtype='object')

# %%
#Group by SA2 suburb
avg_sa2 = aframe[['sa2_name11','SumZScore']].groupby('sa2_name11').mean()

#Group by SA3 area
avg_sa3 = aframe[['sa3_name11','SumZScore']].groupby('sa3_name11').mean()

# %%
avg_sa2 = avg_sa2.reset_index()

# %%
avg_sa2.columns = ['SA2 Name','Walkability Index']
avg_sa2.to_csv('test.csv')
avg_sa2.sort_values('Walkability Index',ascending=True)
# Out:
#                         SA2 Name  Walkability Index
# 25             Pascoe Vale South          -2.406909
# 36                     Thornbury          -2.108694
# 2         Alphington - Fairfield          -2.055192
# 15         Essendon - Aberfeldie          -2.004841
# 37                        Toorak          -1.939547
# 10                        Coburg          -1.852370
# 7                 Brunswick West          -1.725236
# 21                  Moonee Ponds          -1.473731
# 4                     Ascot Vale          -1.463378
# 27     Port Melbourne Industrial          -1.290091
# 23                     Northcote          -1.240260
# 35                 St Kilda East          -1.086723
# 3                       Armadale          -1.016522
# 9   Carlton North - Princes Hill          -0.955973
# 5                      Brunswick          -0.680594
# 14                        Elwood          -0.626253
# 38                 Yarra - North          -0.451671
# ...

# %%
avg_sa3 = avg_sa3.reset_index()
avg_sa3.columns = ['SA3 Name','Walkability Score']

# %%
avg_sa3.sort_values('Walkability Score',ascending=False)
# Out:
#              SA3 Name  Walkability Score
# 3      Melbourne City           2.551466
# 6               Yarra           0.446783
# 4        Port Phillip           0.256828
# 5  Stonnington - West           0.053694
# 0  Brunswick - Coburg          -1.442297
# 2            Essendon          -1.501010
# 1     Darebin - South          -1.705241

# %%
avg_sa2.index.values
# Out:
# array(['Abbotsford', 'Albert Park', 'Alphington - Fairfield', 'Armadale',
#        'Ascot Vale', 'Brunswick', 'Brunswick East', 'Brunswick West',
#        'Carlton', 'Carlton North - Princes Hill', 'Coburg', 'Collingwood',
#        'Docklands', 'East Melbourne', 'Elwood', 'Essendon - Aberfeldie',
#        'Fitzroy', 'Fitzroy North', 'Flemington', 'Kensington', 'Melbourne',
#        'Moonee Ponds', 'North Melbourne', 'Northcote', 'Parkville',
#        'Pascoe Vale South', 'Port Melbourne', 'Port Melbourne Industrial',
#        'Prahran - Windsor', 'Richmond (Vic.)', 'South Melbourne',
#        'South Yarra - East', 'South Yarra - West', 'Southbank', 'St Kilda',
#        'St Kilda East', 'Thornbury', 'Toorak', 'Yarra - North'], dtype=object)

# %%
avg_sa2.idxmin()
# Out:
# SumZScore                        Pascoe Vale South
# Connectivity_ZScore      Port Melbourne Industrial
# AverageDensity_ZScore    Port Melbourne Industrial
# dtype: object

# %%
avg_sa2.idxmax()
# Out:
# SumZScore                Southbank
# Connectivity_ZScore      Melbourne
# AverageDensity_ZScore    Southbank
# dtype: object

# %%
#avg_sub.loc[avg_sub['sa2_name11']=='Carlton']
avg_sa2.columns
# Out:
# Index([u'SumZScore', u'Connectivity_ZScore', u'AverageDensity_ZScore'], dtype='object')
